# %%
import pandas as pd
import py_stringmatching as sm

# %%
sunshine = pd.read_csv('../Data/Outputs_Cleanup/Sunshine/physicians_info.csv',dtype=str)
sunshine.fillna(value='',inplace=True)

# %%
sunshine.head(2)
# Out:
#   Physician_Profile_ID Physician_First_Name Physician_Middle_Name  \
# 0               231734                EINAT                     R
# 1              1153066                PETER             HUNG  NGO
#
#   Physician_Last_Name Physician_Name_Suffix Recipient_City Recipient_State  \
# 0             DUHAMEL                            ENCINITAS              CA
# 1                  VU                         GARDEN GROVE              CA
#
#   Physician_Primary_Type                                Physician_Specialty  \
# 0         MEDICAL DOCTOR  ALLOPATHIC  OSTEOPATHIC PHYSICIANSOBSTETRICS  ...
# 1         MEDICAL DOCTOR       ALLOPATHIC  OSTEOPATHIC PHYSICIANSPEDIATRICS
#
#   Physician_License_State_code1 Physician_License_State_code2  \
# 0                            CA
# 1                            CA
#
#   Physician_License_State_code3 Physician_License_State_code4  \
# 0
# 1
#
#   Physician_License_State_code5 Recipient_Zip_Code
# 0                                        920245110
# 1                                        928442751

# %%
sunshine['Physician_Name_Suffix'].drop_duplicates()
# Out:
# 0
# 26         DR
# 61          I
# 82         JR
# 315        OD
# 587        DO
# 828        MD
# 989         U
# 1050      III
# 2081       MR
# 3227       IV
# 7122       SR
# 7258       II
# 11349     DDS
# 11955       X
# 22363     DPM
# 26911       V
# 27032      VI
# 43701     DMD
# 45256    VIII
# 53875      IX
# 66103     MRS
# Name: Physician_Name_Suffix, dtype: object

# %%
def add_suffix(lname, suffix):
    s = lname + ' ' + suffix
    return s.strip()

sunshine['Physician_Last_Name'] = sunshine.apply(lambda x: add_suffix(x['Physician_Last_Name'],x['Physician_Name_Suffix']),axis=1)

# %%
sunshine[sunshine['Physician_Last_Name'].str.contains('JR')]
# Out:
#       Physician_Profile_ID Physician_First_Name Physician_Middle_Name  \
# 82                  149515                 JACK                     H
# 158                 338244               ROBERT                     E
# 474                 252868                FRANK                     L
# 478                 165366              WILLIAM                 LOGAN
# 488                 699501                 JOHN                     L
# ...                    ...                  ...                   ...
# 66720              6643201               JOSEPH
# 67429              1200901                FRANK                DANIEL
# 67518              1324433              ANTHONY
# 67632               161720                 ROSS                MARTIN
# 69117              1291902               GORDON                THOMAS
#
#       Physician_Last_Name Physician_Name_Suffix Recipient_City  \
# 82             FREIMANNJR                    JR       WHITTIER
# 158                BEERJR                    JR      BRENTWOOD
# 474              ACOSTAJR                    JR    LOS ANGELES
# 478               TONTZJR                    JR      SAN DIEGO
# 488              MADDOXJR                    JR      GREENBRAE
# ...                   ...                   ...            ...
# 66720              DIAZJR                    JR      SAN DIEGO
# 67429           HERRERAJR                    JR         WALNUT
# 67518              SISKJR                    JR    LOS ANGELES
# 67632            HERRONJR                    JR         POMONA
# 69117             FAHEYJR                    JR           LODI
#
#       Recipient_State Physician_Primary_Type  \
# 82                 CA         MEDICAL DOCTOR
# 158                CA         MEDICAL DOCTOR
# 474                CA         MEDICAL DOCTOR
# 478                CA         MEDICAL DOCTOR
# 488                CA         MEDICAL DOCTOR
# ...               ...                    ...
# 66720              CA         MEDICAL DOCTOR
# 67429              CA         MEDICAL DOCTOR
# 67518              CA         MEDICAL DOCTOR
# 67632              CA         MEDICAL DOCTOR
# 69117              CA         MEDICAL DOCTOR
#
#                                      Physician_Specialty  \
# 82     ALLOPATHIC  OSTEOPATHIC PHYSICIANSINTERNAL MED...
# 158        ALLOPATHIC  OSTEOPATHIC PHYSICIANSDERMATOLOGY
# 474    ALLOPATHIC  OSTEOPATHIC PHYSICIANSNEUROLOGICAL...
# 478    ALLOPATHIC  OSTEOPATHIC PHYSICIANSORTHOPAEDIC ...
# 488        ALLOPATHIC  OSTEOPATHIC PHYSICIANSDERMATOLOGY
# ...                                                  ...
# 66720  ALLOPATHIC  OSTEOPATHIC PHYSICIANSGENERAL PRAC...
# 67429          ALLOPATHIC  OSTEOPATHIC PHYSICIANSSURGERY
# 67518  ALLOPATHIC  OSTEOPATHIC PHYSICIANSPATHOLOGYANA...
# 67632  ALLOPATHIC  OSTEOPATHIC PHYSICIANSPATHOLOGYBLO...
# 69117          ALLOPATHIC  OSTEOPATHIC PHYSICIANSSURGERY
#
#       Physician_License_State_code1 Physician_License_State_code2  \
# 82                               CA
# 158                              CA
# 474                              CA
# 478                              CA
# 488                              CA
# ...                             ...                           ...
# 66720                            CA
# 67429                            CA
# 67518                            CA
# 67632                            CA
# 69117                            CA
#
#       Physician_License_State_code3 Physician_License_State_code4  \
# 82
# 158
# 474
# 478
# 488
# ...                             ...                           ...
# 66720
# 67429
# 67518
# 67632
# 69117
#
#       Physician_License_State_code5 Recipient_Zip_Code
# 82                                           906023158
# 158                                              94513
# 474                                              90033
# 478                                              92108
# 488                                          949042015
# ...                             ...                ...
# 66720                                        921031911
# 67429                                            91789
# 67518                                        900950001
# 67632                                            91768
# 69117                                            95240
#
# [393 rows x 15 columns]

# %%
sunshine.rename(columns={'Physician_Profile_ID':'id','Physician_First_Name':'fname','Physician_Last_Name':'fname'})

# %%
sunshine = pd.read_csv('../Data/Physicians_Deduplication/CMS_Sunshine_Physicians.csv',dtype=str)

# %%
part_d = pd.read_csv('../Data/Physicians_Deduplication/Medicare_PartD_Physicians.csv',dtype=str)

# %%
def processType(x):
    s = x.split('|')
    return s[-1]

# %%
def processData(df):
    cols = df.columns.to_list()
    for col in cols:
        df[col] = df[col].astype(str)
        df[col] = df[col].apply(lambda x: x.lower().strip())
    df['type'] = df['type'].apply(lambda x: processType(x))
    df['combined'] = df['fname'] + ' ' + df['lname'] + ' ' + df['city'] + ' ' + df['type']
    return df

# %%
sunshine = processData(sunshine)
part_d = processData(part_d)
# Out:
#         id        fname    lname                  type      city  \
# 0   360308  maheshkumar     vyas  allergy & immunology   anaheim
# 1  1236637     nataliya  kushnir  allergy & immunology  berkeley
#
#                                          combined
# 0   maheshkumar vyas anaheim allergy & immunology
# 1  nataliya kushnir berkeley allergy & immunology

# %% [markdown]
# There are duplicates where the same person has two ids in both dataset.<br>
# The solution is to use the combined column to create a new unique id.<br>
# Then we will create lookup tables for the new ID and the combined string.<br>

# %% [markdown]
# Make the lookup tables

# %%
sunshine.rename(columns={'id':'Physician_Profile_ID'})[['combined','Physician_Profile_ID']].to_csv('../Data/Physicians_Deduplication/Outputs/CMS_Sunshine_Physicians_NewID.csv',index=False)
part_d.rename(columns={'id':'Prscrbr_NPI'})[['combined','Prscrbr_NPI']].to_csv('../Data/Physicians_Deduplication/Outputs/Medicare_PartD_Physicians_NewID.csv',index=False)

# %%
sunshine.drop_duplicates(subset='combined',inplace=True)
part_d.drop_duplicates(subset='combined',inplace=True)

# %%
sunshine_org = sunshine.copy()

# %%
part_d_org = part_d.copy()

# %% [markdown]
# Here we will do a naive matching. Based on just the 'hashID' column. If there is an exact match we will accept this.

# %%
merged_part_d = part_d.merge(right=sunshine,on='combined',how='left')
merged_part_d
# Out:
#               id_x  fname_x     lname_x              type_x        city_x  \
# 0       1326172685     john  janikowski     family practice        apo ap
# 1       1083012520   satvir    dhaliwal             dentist        acampo
# 2       1730178724   cheryl     leonard  nurse practitioner         acton
# 3       1194118836   debbie       welch  nurse practitioner         acton
# 4       1427275114  jeffrey      hempel             dentist         acton
# ...            ...      ...         ...                 ...           ...
# 102642  1790885259  vicente       arano     family practice  yucca valley
# 102643  1851495550  xu shao       huang           optometry  yucca valley
# 102644  1851816888   yizhou       zheng          pharmacist  yucca valley
# 102645  1770672719   yoonho       chang             dentist  yucca valley
# 102646  1376697797  michael      newman   internal medicine     san diego
#
#                                           combined id_y fname_y lname_y  \
# 0           john janikowski apo ap family practice  NaN     NaN     NaN
# 1                   satvir dhaliwal acampo dentist  NaN     NaN     NaN
# 2          cheryl leonard acton nurse practitioner  NaN     NaN     NaN
# 3            debbie welch acton nurse practitioner  NaN     NaN     NaN
# 4                     jeffrey hempel acton dentist  NaN     NaN     NaN
# ...                                            ...  ...     ...     ...
# 102642  vicente arano yucca valley family practice  NaN     NaN     NaN
# 102643        xu shao huang yucca valley optometry  NaN     NaN     NaN
# 102644        yizhou zheng yucca valley pharmacist  NaN     NaN     NaN
# 102645           yoonho chang yucca valley dentist  NaN     NaN     NaN
# 102646  michael newman san diego internal medicine  NaN     NaN     NaN
#
#        type_y city_y
# 0         NaN    NaN
# 1         NaN    NaN
# 2         NaN    NaN
# 3         NaN    NaN
# 4         NaN    NaN
# ...       ...    ...
# 102642    NaN    NaN
# 102643    NaN    NaN
# 102644    NaN    NaN
# 102645    NaN    NaN
# 102646    NaN    NaN
#
# [102647 rows x 11 columns]

# %% [markdown]
# Now we will remove the matches and set them aside. We will do a more careful inspection of the remaining unmatched ones.

# %%
#Setting aside matches, keeping pairs together
matches = merged_part_d.drop(merged_part_d[(merged_part_d['city_x'].isnull()==True) | (merged_part_d['city_y'].isnull()==True)].index)
col = matches.columns.to_list()
col.remove('combined')
matches.drop(columns = col,inplace=True)
matches['combined2'] = matches['combined']
matches.rename(columns={'combined':'part_d','combined2':'sunshine'},inplace=True)
matches.head()
# Out:
#                                             part_d  \
# 9   aaron glucksman agoura hills internal medicine
# 22           bente berman agoura hills dermatology
# 30              daljit mac agoura hills psychiatry
# 31          david drimmer agoura hills dermatology
# 33         debra tennen agoura hills ophthalmology
#
#                                           sunshine
# 9   aaron glucksman agoura hills internal medicine
# 22           bente berman agoura hills dermatology
# 30              daljit mac agoura hills psychiatry
# 31          david drimmer agoura hills dermatology
# 33         debra tennen agoura hills ophthalmology

# %%
part_d.drop(part_d[part_d['combined'].isin(matches['part_d'].to_list())].index,inplace=True)
sunshine.drop(sunshine[sunshine['combined'].isin(matches['sunshine'].to_list())].index,inplace=True)

# %%
del merged_part_d

# %%
#Create a new column in sunshine that is the combined column whitespace tokenized    
#Create a new column in sunshine that is the combined column unigram tokenized
#Create a new column in part_d that is the combined column whitespace tokenized
#Create a new column in part_d that is the combined column unigram tokenized
whitespace_tokenizer = sm.WhitespaceTokenizer()
unigram_tokenizer = sm.QgramTokenizer(qval=2)
sunshine['whitespace_tok'] = sunshine['combined'].apply(lambda x: whitespace_tokenizer.tokenize(x))
sunshine['Qgram_tok'] = sunshine['combined'].apply(lambda x: unigram_tokenizer.tokenize(x))
part_d['whitespace_tok'] = part_d['combined'].apply(lambda x: whitespace_tokenizer.tokenize(x))
part_d['Qgram_tok'] = part_d['combined'].apply(lambda x: unigram_tokenizer.tokenize(x))

# %%
part_d.head()
# Out:
#            id    fname       lname                type    city  \
# 0  1326172685     john  janikowski     family practice  apo ap
# 1  1083012520   satvir    dhaliwal             dentist  acampo
# 2  1730178724   cheryl     leonard  nurse practitioner   acton
# 3  1194118836   debbie       welch  nurse practitioner   acton
# 4  1427275114  jeffrey      hempel             dentist   acton
#
#                                   combined  \
# 0   john janikowski apo ap family practice
# 1           satvir dhaliwal acampo dentist
# 2  cheryl leonard acton nurse practitioner
# 3    debbie welch acton nurse practitioner
# 4             jeffrey hempel acton dentist
#
#                                   whitespace_tok  \
# 0  [john, janikowski, apo, ap, family, practice]
# 1            [satvir, dhaliwal, acampo, dentist]
# 2  [cheryl, leonard, acton, nurse, practitioner]
# 3    [debbie, welch, acton, nurse, practitioner]
# 4              [jeffrey, hempel, acton, dentist]
#
#                                            Qgram_tok
# 0  [#j, jo, oh, hn, n ,  j, ja, an, ni, ik, ko, o...
# 1  [#s, sa, at, tv, vi, ir, r ,  d, dh, ha, al, l...
# 2  [#c, ch, he, er, ry, yl, l ,  l, le, eo, on, n...
# 3  [#d, de, eb, bb, bi, ie, e ,  w, we, el, lc, c...
# 4  [#j, je, ef, ff, fr, re, ey, y ,  h, he, em, m...

# %%
sunshine.head()
# Out:
#         id        fname    lname                  type           city  \
# 0   360308  maheshkumar     vyas  allergy & immunology        anaheim
# 1  1236637     nataliya  kushnir  allergy & immunology       berkeley
# 2   264541         alan  khadavi  allergy & immunology  beverly hills
# 3   122649       joseph     chun  allergy & immunology     buena park
# 4   210594       binita   mandal  allergy & immunology     carmichael
#
#                                           combined  \
# 0    maheshkumar vyas anaheim allergy & immunology
# 1   nataliya kushnir berkeley allergy & immunology
# 2  alan khadavi beverly hills allergy & immunology
# 3      joseph chun buena park allergy & immunology
# 4    binita mandal carmichael allergy & immunology
#
#                                       whitespace_tok  \
# 0  [maheshkumar, vyas, anaheim, allergy, &, immun...
# 1  [nataliya, kushnir, berkeley, allergy, &, immu...
# 2  [alan, khadavi, beverly, hills, allergy, &, im...
# 3  [joseph, chun, buena, park, allergy, &, immuno...
# 4  [binita, mandal, carmichael, allergy, &, immun...
#
#                                            Qgram_tok
# 0  [#m, ma, ah, he, es, sh, hk, ku, um, ma, ar, r...
# 1  [#n, na, at, ta, al, li, iy, ya, a ,  k, ku, u...
# 2  [#a, al, la, an, n ,  k, kh, ha, ad, da, av, v...
# 3  [#j, jo, os, se, ep, ph, h ,  c, ch, hu, un, n...
# 4  [#b, bi, in, ni, it, ta, a ,  m, ma, an, nd, d...

# %%
#We will find matches for the sunshine data in the part_d data
#This is because the sunshine data is the smaller set
#Here is the procedure:    
    #For each row in sunshine
        #Filter the city in part_d
        #Perform Jaccard on the whitespace token set between the remainder and the row
        #Filter out for scores higher than .75
        #If the remaining dataframe is 0
            #Return None
        #Else
            #Grab the highest matching one as the match
            #Save the match into sunshine_match dataframe and part_d_match dataframe
        #Remove the row from both part_d_noDups and sunshine_noDups

# %%
sim_measure = sm.OverlapCoefficient()

# %%
matched = []

# %%
def find_match(sunshine_row):
    #filter part_d for the last name:
    df_partD = part_d[part_d['lname']==sunshine_row['lname']].copy()
    df_partD.drop(df_partD[df_partD['combined'].isin(matched)].index,inplace=True)
    if len(df_partD) == 0:
        #Return None
        return None
    #Perform similarity on the token set between the remainder and the row
    df_partD['score'] = df_partD['Qgram_tok'].apply(lambda x: sim_measure.get_sim_score(x, sunshine_row['Qgram_tok']))
    #Filter out for scores higher than .75
    df_partD.drop(df_partD[df_partD['score']<.8].index,inplace=True)
    #If the remaining dataframe is 0
    if len(df_partD) == 0:
        #Return None
        return None
    #Else if the remaining dataframe is 1
    elif len(df_partD) == 1:
        #Return the remaining row's hash_id
        match = df_partD.iloc[0]['combined']
        matched.append(match)
        return match
    else:
        #Sort the remaining rows by score
        df_partD.sort_values(by=['score'],axis=0,ascending=False,ignore_index=True,inplace=True)
        #Return the highest one
        match = df_partD.iloc[0]['combined']
        matched.append(match)
        return match

# %%
from tqdm import tqdm
import itertools
import multiprocess as mp
import collections

# %%
# %%time
tqdm.pandas(desc="Progress")
sunshine['match'] = sunshine.progress_apply(lambda x: find_match(x),axis=1)
# Out:
# C:\Users\foster\anaconda3\lib\site-packages\tqdm\std.py:697: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# Progress: 100%|██████████████████████████| 53480/53480 [08:57<00:00, 99.49it/s]
# Wall time: 8min 57s

# %%
other_matches = sunshine[sunshine['match'].isnull()==False][['match','combined']].copy()
other_matches.rename(columns={'match':'part_d','combined':'sunshine'},inplace=True)

# %%
matches = pd.concat([matches,other_matches],ignore_index=True)

# %%
part_d.drop(part_d[part_d['combined'].isin(matches['part_d'].to_list())].index,inplace=True)
sunshine.drop(sunshine[sunshine['combined'].isin(matches['sunshine'].to_list())].index,inplace=True)

# %%
sunshine[['id','fname','lname','type','city']].to_csv('../Data/Physicians_Deduplication/Outputs/CMS_Sunshine_Physicians_no_matches.csv',index=False)
part_d[['id','fname','lname','type','city']].to_csv('../Data/Physicians_Deduplication/Outputs/Medicare_PartD_Physicians_no_matches.csv',index=False)

# %%
matches.to_csv('../Data/Physicians_Deduplication/Outputs/Physicians_Deduplicated.csv',index=False)
