# %% [markdown]
# # Dedupe Preparation
# Description: Convert Medicare Part D into a dedupe input by obtaining unique values from Medicare Part D,
# and assigning an Id column to the resulting dataframe.
#
# INPUT: drug_information.csv (From Medicare Part D 2019)
#
# OUTPUT: dataID.csv

# %%
import pandas as pd

# %%
file = '../../Data/Outputs_Cleanup/Sunshine/record_drugs.csv'
df = pd.read_csv(file)
# Out:
# /Users/jonahbreslow/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (22,23,24,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#print(df.columns)
#df.head()
df
# Out:
#          Record_ID Covered_or_Noncovered_Indicator_1  \
# 0        625333457                           COVERED
# 1        625333825                           COVERED
# 2        625335023                           COVERED
# 3        625335025                           COVERED
# 4        625335391                           COVERED
# ...            ...                               ...
# 1208571  752968941                           COVERED
# 1208572  752968943                           COVERED
# 1208573  752968945                           COVERED
# 1208574  752968947                           COVERED
# 1208575  752968949                           COVERED
#
#         Related_Product_Indicator  \
# 0                             YES
# 1                             YES
# 2                             YES
# 3                             YES
# 4                             YES
# ...                           ...
# 1208571                       YES
# 1208572                       YES
# 1208573                       YES
# 1208574                       YES
# 1208575                       YES
#
#         Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1  \
# 0                                                     DRUG
# 1                                                     DRUG
# 2                                                     DRUG
# 3                                                     DRUG
# 4                                                     DRUG
# ...                                                    ...
# 1208571                                             DEVICE
# 1208572                                             DEVICE
# 1208573                                             DEVICE
# 1208574                                             DEVICE
# 1208575                                             DEVICE
#
#         Product_Category_or_Therapeutic_Area_1  \
# 0                                    HEMATINIC
# 1                                    HEMATINIC
# 2                         ADRENOCORTICOSTEROID
# 3                         ADRENOCORTICOSTEROID
# 4                         ADRENOCORTICOSTEROID
# ...                                        ...
# 1208571                         JOINT IMPLANTS
# 1208572                         JOINT IMPLANTS
# 1208573                         JOINT IMPLANTS
# 1208574                         JOINT IMPLANTS
# 1208575                         JOINT IMPLANTS
#
#         Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1  \
# 0                                                 FERRALET
# 1                                                 FERRALET
# 2                                          PREDNISOLONE 25
# 3                                          PREDNISOLONE 25
# 4                                          PREDNISOLONE 25
# ...                                                    ...
# 1208571                    DJO SURGICAL EMPOWR KNEE SYSTEM
# 1208572                  DJO SURGICAL TAPERFILL HIP SYSTEM
# 1208573                         DJO SURGICAL 3DKNEE SYSTEM
# 1208574                         DJO SURGICAL 3DKNEE SYSTEM
# 1208575                         DJO SURGICAL 3DKNEE SYSTEM
#
#          Associated_Drug_or_Biological_NDC_1  \
# 0                                178008990.0
# 1                                178008990.0
# 2                                178058208.0
# 3                                178058208.0
# 4                                178058208.0
# ...                                      ...
# 1208571                                  NaN
# 1208572                                  NaN
# 1208573                                  NaN
# 1208574                                  NaN
# 1208575                                  NaN
#
#         Covered_or_Noncovered_Indicator_2  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1208571                               NaN
# 1208572                               NaN
# 1208573                               NaN
# 1208574                               NaN
# 1208575                               NaN
#
#         Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1208571                                                NaN
# 1208572                                                NaN
# 1208573                                                NaN
# 1208574                                                NaN
# 1208575                                                NaN
#
#         Product_Category_or_Therapeutic_Area_2  ...  \
# 0                                          NaN  ...
# 1                                          NaN  ...
# 2                                          NaN  ...
# 3                                          NaN  ...
# 4                                          NaN  ...
# ...                                        ...  ...
# 1208571                                    NaN  ...
# 1208572                                    NaN  ...
# 1208573                                    NaN  ...
# 1208574                                    NaN  ...
# 1208575                                    NaN  ...
#
#         Covered_or_Noncovered_Indicator_4  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 1208571                               NaN
# 1208572                               NaN
# 1208573                               NaN
# 1208574                               NaN
# 1208575                               NaN
#
#          Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1208571                                                NaN
# 1208572                                                NaN
# 1208573                                                NaN
# 1208574                                                NaN
# 1208575                                                NaN
#
#         Product_Category_or_Therapeutic_Area_4  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 1208571                                    NaN
# 1208572                                    NaN
# 1208573                                    NaN
# 1208574                                    NaN
# 1208575                                    NaN
#
#         Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1208571                                                NaN
# 1208572                                                NaN
# 1208573                                                NaN
# 1208574                                                NaN
# 1208575                                                NaN
#
#         Associated_Drug_or_Biological_NDC_4 Covered_or_Noncovered_Indicator_5  \
# 0                                       NaN                               NaN
# 1                                       NaN                               NaN
# 2                                       NaN                               NaN
# 3                                       NaN                               NaN
# 4                                       NaN                               NaN
# ...                                     ...                               ...
# 1208571                                 NaN                               NaN
# 1208572                                 NaN                               NaN
# 1208573                                 NaN                               NaN
# 1208574                                 NaN                               NaN
# 1208575                                 NaN                               NaN
#
#          Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1208571                                                NaN
# 1208572                                                NaN
# 1208573                                                NaN
# 1208574                                                NaN
# 1208575                                                NaN
#
#         Product_Category_or_Therapeutic_Area_5  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 1208571                                    NaN
# 1208572                                    NaN
# 1208573                                    NaN
# 1208574                                    NaN
# 1208575                                    NaN
#
#         Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1208571                                                NaN
# 1208572                                                NaN
# 1208573                                                NaN
# 1208574                                                NaN
# 1208575                                                NaN
#
#         Associated_Drug_or_Biological_NDC_5
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1208571                                 NaN
# 1208572                                 NaN
# 1208573                                 NaN
# 1208574                                 NaN
# 1208575                                 NaN
#
# [1208576 rows x 27 columns]

# %%
df_indicator = df[[
    'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_1',
    'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_2',
    'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_3',
    'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_4',
    'Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_5',
    'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_1',
    'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_2',
    'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_3',
    'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_4',
    'Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_5'
]]

for each in range(5):
    df_indicator['drug_' + str(each + 1)] = df_indicator['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_' + str(each + 1)] + "#" +  df_indicator['Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_' + str(each + 1)]

df_indicator = df_indicator[['drug_1', 'drug_2', 'drug_3', 'drug_4', 'drug_5',]]
df_melted = df_indicator.melt(id_vars=None, value_vars=[df_indicator.columns])
df_melted.dropna(inplace=True)
df_melted = df_melted['value'].str.split('#', expand=True)
df_melted.drop_duplicates(inplace=True)
df_melted.columns = ['brand_name', 'Indicator']
df_melted = df_melted[df_melted.Indicator != 'DEVICE']
df_melted = df_melted[['brand_name']]
df_melted.to_csv('../../Data/Outputs_Cleanup/Sunshine/sunshine_drugs_distinct.csv', index=False)
# Out:
# /var/folders/_7/7cv8089x2q1_td7nlck8f7lc0000gn/T/ipykernel_5792/1104183984.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_indicator['drug_' + str(each + 1)] = df_indicator['Name_of_Drug_or_Biological_or_Device_or_Medical_Supply_' + str(each + 1)] + "#" +  df_indicator['Indicate_Drug_or_Biological_or_Device_or_Medical_Supply_' + str(each + 1)]
