# %% [markdown]
# # Dedupe Preparation
# Description: Convert openfda into a dedupe input by obtaining unique values from openfda,
# and assigning an Id column to the resulting dataframe.
#
# INPUT: openfda_processed.csv (From openfda json to table)
#
# OUTPUT: dataID.csv

# %%
import pandas as pd
import numpy as np
import pickle
import re
import os

# %%
def remove_punc(string):
    '''
    takes in a string and removed all punctuation.
    '''
    return re.sub(r'[^\w\s]','',string)

def preProcess(df):
    '''
    takes a dataframe, applies the remove_punc function
    and then upper cases all text columns
    '''
    df = df.applymap(lambda s:remove_punc(s).upper() if isinstance(s, str) else s)
    return df

# %%
file = '../../Data/Outputs_Cleanup/FDA/openfda_processed.csv'
df = pd.read_csv(file)
df.head()
# Out:
#    fda_drug_id                brand_name  \
# 0            6                    Dentox
# 1           19       Cactus Cinis Avenae
# 2           22                Zinc Oxide
# 3           23          good sense nasal
# 4           33  Amantadine Hydrochloride
#
#                                         generic_name  \
# 0  BERBERIS VULGARIS, GLYCYRRHIZA GLABRA, LAPPA M...
# 1                                CACTUS CINIS AVENAE
# 2                                         ZINC OXIDE
# 3                                  OXYMETAZOLINE HCL
# 4                           AMANTADINE HYDROCHLORIDE
#
#              manufacturer_name product_ndc             product_type    route  \
# 0  BioActive Nutritional, Inc.  43857-0039           HUMAN OTC DRUG     ORAL
# 1          Uriel Pharmacy Inc.  48951-3239           HUMAN OTC DRUG     ORAL
# 2       Ultra Seal Corporation   42213-365           HUMAN OTC DRUG  TOPICAL
# 3           L. Perrigo Company   0113-0388           HUMAN OTC DRUG    NASAL
# 4          Strides Pharma Inc.   42543-493  HUMAN PRESCRIPTION DRUG     ORAL
#
#                                       substance_name  \
# 0  BERBERIS VULGARIS ROOT BARK, GLYCYRRHIZA GLABR...
# 1  MAGNESIUM PHOSPHATE, TRIBASIC, PENTAHYDRATE, S...
# 2                                         ZINC OXIDE
# 3                        OXYMETAZOLINE HYDROCHLORIDE
# 4                           AMANTADINE HYDROCHLORIDE
#
#                                  spl_id                            spl_set_id  \
# 0  e4462f59-9ba5-43a9-9b2b-3e5a807545dd  ae51c063-63b4-45cc-b8d0-e98584b65a66
# 1  b6c13079-0ed0-0d79-e053-2a95a90a8d7c  b6c13079-0ecf-0d79-e053-2a95a90a8d7c
# 2  b4c9e519-4ee3-4cba-9338-148b9cade2ac  e45ac82c-508c-4c41-ba2c-f48d36bc63fe
# 3  244eff85-348f-42a5-a26e-aaaee89bfc69  5d42adb9-3625-4072-a6b1-29a229f255c8
# 4  05b79d14-440a-4526-bccf-8bc26a2ec8a0  e4d8f36f-d668-4728-8dca-b1c22bd9aedb
#
#    ...                                     pharm_class_pe  \
# 0  ...  Increased Histamine Release [PE], Cell-mediate...
# 1  ...                                                NaN
# 2  ...                                                NaN
# 3  ...                                                NaN
# 4  ...                                                NaN
#
#                                       pharm_class_cs  \
# 0  Allergens [CS], Dietary Proteins [CS], Plant P...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                 unii application_number  \
# 0  1TH8Q20J0U, 2788Z9758H, 597E9BI3Z3, 11E6VI8VEG...                NaN
# 1     453COF7817, 7114SV0MYK, 6OM09RPY36, OZ0E5Y15PZ                NaN
# 2                                         SOI2LOH54Z            part347
# 3                                         K89MJ0S5VY            part341
# 4                                         M6Q1EO9TD0         ANDA209047
#
#      rxcui            upc original_packager_product_ndc pharm_class_moa  \
# 0      NaN            NaN                           NaN             NaN
# 1      NaN            NaN                           NaN             NaN
# 2   198911  0001500365569                           NaN             NaN
# 3  1000990            NaN                           NaN             NaN
# 4   849389  0342543493018                           NaN             NaN
#
#   manufacturer_name_normalized fda_manuf_id
# 0    BIOACTIVE NUTRITIONAL INC            0
# 1           URIEL PHARMACY INC            1
# 2       ULTRA SEAL CORPORATION            2
# 3            L PERRIGO COMPANY            3
# 4           STRIDES PHARMA INC            4
#
# [5 rows x 24 columns]

# %%
# df.reset_index(inplace=True)
# df.rename(columns={"index": "fda_drug_id"}, inplace=True)
df = df[df.product_type != 'HUMAN OTC DRUG']

df.dropna(subset=['brand_name'], inplace=True)
df['is_original_packager'] = np.where(df.is_original_packager==True,1,0)
df = df[df.is_original_packager == 1]
display(df.head())
print(df.columns)
# Out:
#     fda_drug_id                     brand_name                   generic_name  \
# 4            33       Amantadine Hydrochloride       AMANTADINE HYDROCHLORIDE
# 8            56           cholestyramine light           CHOLESTYRAMINE LIGHT
# 10           59           Sulfacetamide Sodium           SULFACETAMIDE SODIUM
# 11           67      Dicyclomine hydrochloride      DICYCLOMINE HYDROCHLORIDE
# 19          116  Magnesium Sulfate in Dextrose  MAGNESIUM SULFATE IN DEXTROSE
#
#                  manufacturer_name product_ndc             product_type  \
# 4              Strides Pharma Inc.   42543-493  HUMAN PRESCRIPTION DRUG
# 8                   Eon Labs, Inc.   0185-0939  HUMAN PRESCRIPTION DRUG
# 10      Bausch & Lomb Incorporated   24208-670  HUMAN PRESCRIPTION DRUG
# 11  Hikma Pharmaceuticals USA Inc.   0143-3126  HUMAN PRESCRIPTION DRUG
# 19                   Hospira, Inc.   0409-6727  HUMAN PRESCRIPTION DRUG
#
#           route                  substance_name  \
# 4          ORAL        AMANTADINE HYDROCHLORIDE
# 8          ORAL                  CHOLESTYRAMINE
# 10   OPHTHALMIC            SULFACETAMIDE SODIUM
# 11         ORAL       DICYCLOMINE HYDROCHLORIDE
# 19  INTRAVENOUS  MAGNESIUM SULFATE HEPTAHYDRATE
#
#                                   spl_id  \
# 4   05b79d14-440a-4526-bccf-8bc26a2ec8a0
# 8   a060c45e-83ef-4c9f-b54a-89e5241706e2
# 10  98ac569a-010a-4804-9b78-a28b54899c99
# 11  008f2526-f7fc-4c9b-939d-04661bcec6be
# 19  1a9001bb-2fa0-4d2b-bd9c-19c3c2705a01
#
#                               spl_set_id  ... pharm_class_pe  pharm_class_cs  \
# 4   e4d8f36f-d668-4728-8dca-b1c22bd9aedb  ...            NaN             NaN
# 8   a7dd335a-6413-446e-8098-d4f97e935986  ...            NaN             NaN
# 10  6c1b2658-e756-4f31-9bc8-f99a0baa4637  ...            NaN             NaN
# 11  1415ad6f-8d92-415c-ae80-5af0795a78c0  ...            NaN             NaN
# 19  03ebeabb-8386-4af4-3086-bdf3c3fc4a5a  ...            NaN             NaN
#
#           unii application_number    rxcui            upc  \
# 4   M6Q1EO9TD0         ANDA209047   849389  0342543493018
# 8   4B33BGI082         ANDA074558  1801279  0301850939978
# 10  4NRT660KJQ         ANDA040066  1006120            NaN
# 11  CQ903KQA31         ANDA040204   991061            NaN
# 19  SK47B8698T          NDA020488   829757            NaN
#
#    original_packager_product_ndc                   pharm_class_moa  \
# 4                            NaN                               NaN
# 8                            NaN  Bile-acid Binding Activity [MoA]
# 10                           NaN                               NaN
# 11                           NaN                               NaN
# 19                           NaN                               NaN
#
#      manufacturer_name_normalized fda_manuf_id
# 4              STRIDES PHARMA INC            4
# 8                    EON LABS INC            8
# 10      BAUSCH  LOMB INCORPORATED           10
# 11  HIKMA PHARMACEUTICALS USA INC           11
# 19                    HOSPIRA INC           19
#
# [5 rows x 24 columns]
# Index(['fda_drug_id', 'brand_name', 'generic_name', 'manufacturer_name',
#        'product_ndc', 'product_type', 'route', 'substance_name', 'spl_id',
#        'spl_set_id', 'package_ndc', 'is_original_packager', 'nui',
#        'pharm_class_epc', 'pharm_class_pe', 'pharm_class_cs', 'unii',
#        'application_number', 'rxcui', 'upc', 'original_packager_product_ndc',
#        'pharm_class_moa', 'manufacturer_name_normalized', 'fda_manuf_id'],
#       dtype='object')

# %%
df = preProcess(df)
display(df.head())
df.shape
# Out:
#     fda_drug_id                     brand_name                   generic_name  \
# 4            33       AMANTADINE HYDROCHLORIDE       AMANTADINE HYDROCHLORIDE
# 8            56           CHOLESTYRAMINE LIGHT           CHOLESTYRAMINE LIGHT
# 10           59           SULFACETAMIDE SODIUM           SULFACETAMIDE SODIUM
# 11           67      DICYCLOMINE HYDROCHLORIDE      DICYCLOMINE HYDROCHLORIDE
# 19          116  MAGNESIUM SULFATE IN DEXTROSE  MAGNESIUM SULFATE IN DEXTROSE
#
#                 manufacturer_name product_ndc             product_type  \
# 4              STRIDES PHARMA INC    42543493  HUMAN PRESCRIPTION DRUG
# 8                    EON LABS INC    01850939  HUMAN PRESCRIPTION DRUG
# 10      BAUSCH  LOMB INCORPORATED    24208670  HUMAN PRESCRIPTION DRUG
# 11  HIKMA PHARMACEUTICALS USA INC    01433126  HUMAN PRESCRIPTION DRUG
# 19                    HOSPIRA INC    04096727  HUMAN PRESCRIPTION DRUG
#
#           route                  substance_name  \
# 4          ORAL        AMANTADINE HYDROCHLORIDE
# 8          ORAL                  CHOLESTYRAMINE
# 10   OPHTHALMIC            SULFACETAMIDE SODIUM
# 11         ORAL       DICYCLOMINE HYDROCHLORIDE
# 19  INTRAVENOUS  MAGNESIUM SULFATE HEPTAHYDRATE
#
#                               spl_id                        spl_set_id  ...  \
# 4   05B79D14440A4526BCCF8BC26A2EC8A0  E4D8F36FD66847288DCAB1C22BD9AEDB  ...
# 8   A060C45E83EF4C9FB54A89E5241706E2  A7DD335A6413446E8098D4F97E935986  ...
# 10  98AC569A010A48049B78A28B54899C99  6C1B2658E7564F319BC8F99A0BAA4637  ...
# 11  008F2526F7FC4C9B939D04661BCEC6BE  1415AD6F8D92415CAE805AF0795A78C0  ...
# 19  1A9001BB2FA04D2BBD9C19C3C2705A01  03EBEABB83864AF43086BDF3C3FC4A5A  ...
#
#    pharm_class_pe  pharm_class_cs        unii application_number    rxcui  \
# 4             NaN             NaN  M6Q1EO9TD0         ANDA209047   849389
# 8             NaN             NaN  4B33BGI082         ANDA074558  1801279
# 10            NaN             NaN  4NRT660KJQ         ANDA040066  1006120
# 11            NaN             NaN  CQ903KQA31         ANDA040204   991061
# 19            NaN             NaN  SK47B8698T          NDA020488   829757
#
#               upc original_packager_product_ndc  \
# 4   0342543493018                           NaN
# 8   0301850939978                           NaN
# 10            NaN                           NaN
# 11            NaN                           NaN
# 19            NaN                           NaN
#
#                   pharm_class_moa   manufacturer_name_normalized fda_manuf_id
# 4                             NaN             STRIDES PHARMA INC            4
# 8   BILEACID BINDING ACTIVITY MOA                   EON LABS INC            8
# 10                            NaN      BAUSCH  LOMB INCORPORATED           10
# 11                            NaN  HIKMA PHARMACEUTICALS USA INC           11
# 19                            NaN                    HOSPIRA INC           19
#
# [5 rows x 24 columns]
# (15186, 24)

# %%
columns = ['fda_drug_id', 'brand_name', 'generic_name', 'product_type', 'route',
       'substance_name', 'manufacturer_name', 'pharm_class_epc', 'pharm_class_pe',
       'pharm_class_cs', 'pharm_class_moa']

groupby_cols = ['brand_name', 'generic_name', 'product_type', 'route',
       'substance_name', 'manufacturer_name', 'pharm_class_epc', 'pharm_class_pe',
       'pharm_class_cs', 'pharm_class_moa']

fill_na_cols = ['pharm_class_epc', 'pharm_class_pe', 'pharm_class_cs', 'pharm_class_moa']
for col in fill_na_cols:
    df[col] = df[col].fillna('""')

df = df[columns]
df.drop_duplicates(groupby_cols, inplace=True)
display(df)
#display(df.groupby(groupby_cols).count().sort_values('brand_name', ascending=False))
df.columns
# Out:
#        fda_drug_id                     brand_name  \
# 4               33       AMANTADINE HYDROCHLORIDE
# 8               56           CHOLESTYRAMINE LIGHT
# 10              59           SULFACETAMIDE SODIUM
# 11              67      DICYCLOMINE HYDROCHLORIDE
# 19             116  MAGNESIUM SULFATE IN DEXTROSE
# ...            ...                            ...
# 98029       193085                      EZETIMIBE
# 98041       193097                       ABACAVIR
# 98046       193102                      ALBUTEROL
# 98065       193121                       NITROGEN
# 98076       193133          PCXX STRAWBERRY APF F
#
#                         generic_name             product_type  \
# 4           AMANTADINE HYDROCHLORIDE  HUMAN PRESCRIPTION DRUG
# 8               CHOLESTYRAMINE LIGHT  HUMAN PRESCRIPTION DRUG
# 10              SULFACETAMIDE SODIUM  HUMAN PRESCRIPTION DRUG
# 11         DICYCLOMINE HYDROCHLORIDE  HUMAN PRESCRIPTION DRUG
# 19     MAGNESIUM SULFATE IN DEXTROSE  HUMAN PRESCRIPTION DRUG
# ...                              ...                      ...
# 98029                      EZETIMIBE  HUMAN PRESCRIPTION DRUG
# 98041                       ABACAVIR  HUMAN PRESCRIPTION DRUG
# 98046                      ALBUTEROL  HUMAN PRESCRIPTION DRUG
# 98065                       NITROGEN  HUMAN PRESCRIPTION DRUG
# 98076                SODIUM FLUORIDE  HUMAN PRESCRIPTION DRUG
#
#                         route                  substance_name  \
# 4                        ORAL        AMANTADINE HYDROCHLORIDE
# 8                        ORAL                  CHOLESTYRAMINE
# 10                 OPHTHALMIC            SULFACETAMIDE SODIUM
# 11                       ORAL       DICYCLOMINE HYDROCHLORIDE
# 19                INTRAVENOUS  MAGNESIUM SULFATE HEPTAHYDRATE
# ...                       ...                             ...
# 98029                    ORAL                       EZETIMIBE
# 98041                    ORAL                ABACAVIR SULFATE
# 98046                    ORAL               ALBUTEROL SULFATE
# 98065  RESPIRATORY INHALATION                        NITROGEN
# 98076          DENTAL TOPICAL                 SODIUM FLUORIDE
#
#                    manufacturer_name  \
# 4                 STRIDES PHARMA INC
# 8                       EON LABS INC
# 10         BAUSCH  LOMB INCORPORATED
# 11     HIKMA PHARMACEUTICALS USA INC
# 19                       HOSPIRA INC
# ...                              ...
# 98029  ZYDUS PHARMACEUTICALS USA INC
# 98041     XLCARE PHARMACEUTICALS INC
# 98046     VIRTUS PHARMACEUTICALS LLC
# 98065            HELGET GAS PRODUCTS
# 98076            ROSS HEALTHCARE INC
#
#                                     pharm_class_epc  \
# 4                                                ""
# 8                         BILE ACID SEQUESTRANT EPC
# 10                                               ""
# 11                                               ""
# 19                                               ""
# ...                                             ...
# 98029  DIETARY CHOLESTEROL ABSORPTION INHIBITOR EPC
# 98041                                            ""
# 98046                                            ""
# 98065                                            ""
# 98076                                            ""
#
#                             pharm_class_pe pharm_class_cs  \
# 4                                       ""             ""
# 8                                       ""             ""
# 10                                      ""             ""
# 11                                      ""             ""
# 19                                      ""             ""
# ...                                    ...            ...
# 98029  DECREASED CHOLESTEROL ABSORPTION PE             ""
# 98041                                   ""             ""
# 98046                                   ""             ""
# 98065                                   ""             ""
# 98076                                   ""             ""
#
#                      pharm_class_moa
# 4                                 ""
# 8      BILEACID BINDING ACTIVITY MOA
# 10                                ""
# 11                                ""
# 19                                ""
# ...                              ...
# 98029                             ""
# 98041                             ""
# 98046                             ""
# 98065                             ""
# 98076                             ""
#
# [13045 rows x 11 columns]
# Index(['fda_drug_id', 'brand_name', 'generic_name', 'product_type', 'route',
#        'substance_name', 'manufacturer_name', 'pharm_class_epc',
#        'pharm_class_pe', 'pharm_class_cs', 'pharm_class_moa'],
#       dtype='object')

# %%
df.groupby('brand_name').count().sort_values('substance_name')
df_grouped = df.groupby('brand_name').agg(list)
#df_grouped[''] = df.groupby('brand_name')['route'].apply(list)

# %%
#df[df.brand_name == 'LIDOCAINE HYDROCHLORIDE']

# %%
#os.getcwd()
pickle.dump(df_grouped, open( "../../Data/Outputs_Cleanup/FDA/Openfda_Drug_Deduplicated.p", "wb" ) )
df_grouped.to_csv('../../Data/Outputs_Cleanup/FDA/Openfda_Drug_Deduplicated.csv')
#df_grouped
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/_7/7cv8089x2q1_td7nlck8f7lc0000gn/T/ipykernel_7990/682094451.py in <module>
#       1 #os.getcwd()
# ----> 2 pickle.dump(df_grouped.compute(), open( "../../Data/Outputs_Cleanup/FDA/Openfda_Drug_Deduplicated.p", "wb" ) )
#       3 df_grouped.to_csv('../../Data/Outputs_Cleanup/FDA/Openfda_Drug_Deduplicated.csv')
#       4 #df_grouped
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'compute'
