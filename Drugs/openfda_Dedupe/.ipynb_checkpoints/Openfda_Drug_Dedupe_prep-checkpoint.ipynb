# %% [markdown]
# # Dedupe Preparation
# Description: Convert openfda into a dedupe input by obtaining unique values from openfda,
# and assigning an Id column to the resulting dataframe.
#
# INPUT: openfda_processed.csv (From openfda json to table)
#
# OUTPUT: dataID.csv

# %%
import pandas as pd
import numpy as np
import re
import os

# %%
def remove_punc(string):
    '''
    takes in a string and removed all punctuation.
    '''
    return re.sub(r'[^\w\s]','',string)

def preProcess(df):
    '''
    takes a dataframe, applies the remove_punc function
    and then upper cases all text columns
    '''
    df = df.applymap(lambda s:remove_punc(s).upper() if isinstance(s, str) else s)
    return df

# %%
file = 'openfda_processed.csv'
df = pd.read_csv(file)


df.reset_index(inplace=True)
df.rename(columns={"index": "fda_drug_id"}, inplace=True)
df = df[df.product_type != 'HUMAN OTC DRUG']

df.dropna(subset=['brand_name'], inplace=True)
df['is_original_packager'] = np.where(df.is_original_packager==True,1,0)
df = df[df.is_original_packager == 1]
display(df.head())
print(df.columns)
# Out:
#     fda_drug_id  Unnamed: 0                     brand_name  \
# 4             4          33       Amantadine Hydrochloride
# 8             8          56           cholestyramine light
# 10           10          59           Sulfacetamide Sodium
# 11           11          67      Dicyclomine hydrochloride
# 19           19         116  Magnesium Sulfate in Dextrose
#
#                      generic_name               manufacturer_name product_ndc  \
# 4        AMANTADINE HYDROCHLORIDE             Strides Pharma Inc.   42543-493
# 8            CHOLESTYRAMINE LIGHT                  Eon Labs, Inc.   0185-0939
# 10           SULFACETAMIDE SODIUM      Bausch & Lomb Incorporated   24208-670
# 11      DICYCLOMINE HYDROCHLORIDE  Hikma Pharmaceuticals USA Inc.   0143-3126
# 19  MAGNESIUM SULFATE IN DEXTROSE                   Hospira, Inc.   0409-6727
#
#                product_type        route                  substance_name  \
# 4   HUMAN PRESCRIPTION DRUG         ORAL        AMANTADINE HYDROCHLORIDE
# 8   HUMAN PRESCRIPTION DRUG         ORAL                  CHOLESTYRAMINE
# 10  HUMAN PRESCRIPTION DRUG   OPHTHALMIC            SULFACETAMIDE SODIUM
# 11  HUMAN PRESCRIPTION DRUG         ORAL       DICYCLOMINE HYDROCHLORIDE
# 19  HUMAN PRESCRIPTION DRUG  INTRAVENOUS  MAGNESIUM SULFATE HEPTAHYDRATE
#
#                                   spl_id  ...                       nui  \
# 4   05b79d14-440a-4526-bccf-8bc26a2ec8a0  ...                       NaN
# 8   a060c45e-83ef-4c9f-b54a-89e5241706e2  ...  N0000180292, N0000175365
# 10  98ac569a-010a-4804-9b78-a28b54899c99  ...                       NaN
# 11  008f2526-f7fc-4c9b-939d-04661bcec6be  ...                       NaN
# 19  1a9001bb-2fa0-4d2b-bd9c-19c3c2705a01  ...                       NaN
#
#                 pharm_class_epc  pharm_class_pe pharm_class_cs        unii  \
# 4                           NaN             NaN            NaN  M6Q1EO9TD0
# 8   Bile Acid Sequestrant [EPC]             NaN            NaN  4B33BGI082
# 10                          NaN             NaN            NaN  4NRT660KJQ
# 11                          NaN             NaN            NaN  CQ903KQA31
# 19                          NaN             NaN            NaN  SK47B8698T
#
#    application_number    rxcui            upc original_packager_product_ndc  \
# 4          ANDA209047   849389  0342543493018                           NaN
# 8          ANDA074558  1801279  0301850939978                           NaN
# 10         ANDA040066  1006120            NaN                           NaN
# 11         ANDA040204   991061            NaN                           NaN
# 19          NDA020488   829757            NaN                           NaN
#
#                      pharm_class_moa
# 4                                NaN
# 8   Bile-acid Binding Activity [MoA]
# 10                               NaN
# 11                               NaN
# 19                               NaN
#
# [5 rows x 23 columns]
# Index(['fda_drug_id', 'Unnamed: 0', 'brand_name', 'generic_name',
#        'manufacturer_name', 'product_ndc', 'product_type', 'route',
#        'substance_name', 'spl_id', 'spl_set_id', 'package_ndc',
#        'is_original_packager', 'nui', 'pharm_class_epc', 'pharm_class_pe',
#        'pharm_class_cs', 'unii', 'application_number', 'rxcui', 'upc',
#        'original_packager_product_ndc', 'pharm_class_moa'],
#       dtype='object')

# %%
df = preProcess(df)
display(df.head())
df.shape
# Out:
#     fda_drug_id  Unnamed: 0                     brand_name  \
# 4             4          33       AMANTADINE HYDROCHLORIDE
# 8             8          56           CHOLESTYRAMINE LIGHT
# 10           10          59           SULFACETAMIDE SODIUM
# 11           11          67      DICYCLOMINE HYDROCHLORIDE
# 19           19         116  MAGNESIUM SULFATE IN DEXTROSE
#
#                      generic_name              manufacturer_name product_ndc  \
# 4        AMANTADINE HYDROCHLORIDE             STRIDES PHARMA INC    42543493
# 8            CHOLESTYRAMINE LIGHT                   EON LABS INC    01850939
# 10           SULFACETAMIDE SODIUM      BAUSCH  LOMB INCORPORATED    24208670
# 11      DICYCLOMINE HYDROCHLORIDE  HIKMA PHARMACEUTICALS USA INC    01433126
# 19  MAGNESIUM SULFATE IN DEXTROSE                    HOSPIRA INC    04096727
#
#                product_type        route                  substance_name  \
# 4   HUMAN PRESCRIPTION DRUG         ORAL        AMANTADINE HYDROCHLORIDE
# 8   HUMAN PRESCRIPTION DRUG         ORAL                  CHOLESTYRAMINE
# 10  HUMAN PRESCRIPTION DRUG   OPHTHALMIC            SULFACETAMIDE SODIUM
# 11  HUMAN PRESCRIPTION DRUG         ORAL       DICYCLOMINE HYDROCHLORIDE
# 19  HUMAN PRESCRIPTION DRUG  INTRAVENOUS  MAGNESIUM SULFATE HEPTAHYDRATE
#
#                               spl_id  ...                      nui  \
# 4   05B79D14440A4526BCCF8BC26A2EC8A0  ...                      NaN
# 8   A060C45E83EF4C9FB54A89E5241706E2  ...  N0000180292 N0000175365
# 10  98AC569A010A48049B78A28B54899C99  ...                      NaN
# 11  008F2526F7FC4C9B939D04661BCEC6BE  ...                      NaN
# 19  1A9001BB2FA04D2BBD9C19C3C2705A01  ...                      NaN
#
#               pharm_class_epc  pharm_class_pe pharm_class_cs        unii  \
# 4                         NaN             NaN            NaN  M6Q1EO9TD0
# 8   BILE ACID SEQUESTRANT EPC             NaN            NaN  4B33BGI082
# 10                        NaN             NaN            NaN  4NRT660KJQ
# 11                        NaN             NaN            NaN  CQ903KQA31
# 19                        NaN             NaN            NaN  SK47B8698T
#
#    application_number    rxcui            upc original_packager_product_ndc  \
# 4          ANDA209047   849389  0342543493018                           NaN
# 8          ANDA074558  1801279  0301850939978                           NaN
# 10         ANDA040066  1006120            NaN                           NaN
# 11         ANDA040204   991061            NaN                           NaN
# 19          NDA020488   829757            NaN                           NaN
#
#                   pharm_class_moa
# 4                             NaN
# 8   BILEACID BINDING ACTIVITY MOA
# 10                            NaN
# 11                            NaN
# 19                            NaN
#
# [5 rows x 23 columns]
# (15186, 23)

# %%
columns = ['fda_drug_id', 'brand_name', 'generic_name', 'product_type', 'route',
       'substance_name', 'manufacturer_name', 'pharm_class_epc', 'pharm_class_pe',
       'pharm_class_cs', 'pharm_class_moa']

groupby_cols = ['brand_name', 'generic_name', 'product_type', 'route',
       'substance_name', 'manufacturer_name', 'pharm_class_epc', 'pharm_class_pe',
       'pharm_class_cs', 'pharm_class_moa']

fill_na_cols = ['pharm_class_epc', 'pharm_class_pe', 'pharm_class_cs', 'pharm_class_moa']
for col in fill_na_cols:
    df[col] = df[col].fillna('""')

df = df[columns]
df.drop_duplicates(groupby_cols, inplace=True)
display(df)
#display(df.groupby(groupby_cols).count().sort_values('brand_name', ascending=False))
df.columns
# Out:
#        fda_drug_id                     brand_name  \
# 4                4       AMANTADINE HYDROCHLORIDE
# 8                8           CHOLESTYRAMINE LIGHT
# 10              10           SULFACETAMIDE SODIUM
# 11              11      DICYCLOMINE HYDROCHLORIDE
# 19              19  MAGNESIUM SULFATE IN DEXTROSE
# ...            ...                            ...
# 98029        98029                      EZETIMIBE
# 98041        98041                       ABACAVIR
# 98046        98046                      ALBUTEROL
# 98065        98065                       NITROGEN
# 98076        98076          PCXX STRAWBERRY APF F
#
#                         generic_name             product_type  \
# 4           AMANTADINE HYDROCHLORIDE  HUMAN PRESCRIPTION DRUG
# 8               CHOLESTYRAMINE LIGHT  HUMAN PRESCRIPTION DRUG
# 10              SULFACETAMIDE SODIUM  HUMAN PRESCRIPTION DRUG
# 11         DICYCLOMINE HYDROCHLORIDE  HUMAN PRESCRIPTION DRUG
# 19     MAGNESIUM SULFATE IN DEXTROSE  HUMAN PRESCRIPTION DRUG
# ...                              ...                      ...
# 98029                      EZETIMIBE  HUMAN PRESCRIPTION DRUG
# 98041                       ABACAVIR  HUMAN PRESCRIPTION DRUG
# 98046                      ALBUTEROL  HUMAN PRESCRIPTION DRUG
# 98065                       NITROGEN  HUMAN PRESCRIPTION DRUG
# 98076                SODIUM FLUORIDE  HUMAN PRESCRIPTION DRUG
#
#                         route                  substance_name  \
# 4                        ORAL        AMANTADINE HYDROCHLORIDE
# 8                        ORAL                  CHOLESTYRAMINE
# 10                 OPHTHALMIC            SULFACETAMIDE SODIUM
# 11                       ORAL       DICYCLOMINE HYDROCHLORIDE
# 19                INTRAVENOUS  MAGNESIUM SULFATE HEPTAHYDRATE
# ...                       ...                             ...
# 98029                    ORAL                       EZETIMIBE
# 98041                    ORAL                ABACAVIR SULFATE
# 98046                    ORAL               ALBUTEROL SULFATE
# 98065  RESPIRATORY INHALATION                        NITROGEN
# 98076          DENTAL TOPICAL                 SODIUM FLUORIDE
#
#                    manufacturer_name  \
# 4                 STRIDES PHARMA INC
# 8                       EON LABS INC
# 10         BAUSCH  LOMB INCORPORATED
# 11     HIKMA PHARMACEUTICALS USA INC
# 19                       HOSPIRA INC
# ...                              ...
# 98029  ZYDUS PHARMACEUTICALS USA INC
# 98041     XLCARE PHARMACEUTICALS INC
# 98046     VIRTUS PHARMACEUTICALS LLC
# 98065            HELGET GAS PRODUCTS
# 98076            ROSS HEALTHCARE INC
#
#                                     pharm_class_epc  \
# 4                                                ""
# 8                         BILE ACID SEQUESTRANT EPC
# 10                                               ""
# 11                                               ""
# 19                                               ""
# ...                                             ...
# 98029  DIETARY CHOLESTEROL ABSORPTION INHIBITOR EPC
# 98041                                            ""
# 98046                                            ""
# 98065                                            ""
# 98076                                            ""
#
#                             pharm_class_pe pharm_class_cs  \
# 4                                       ""             ""
# 8                                       ""             ""
# 10                                      ""             ""
# 11                                      ""             ""
# 19                                      ""             ""
# ...                                    ...            ...
# 98029  DECREASED CHOLESTEROL ABSORPTION PE             ""
# 98041                                   ""             ""
# 98046                                   ""             ""
# 98065                                   ""             ""
# 98076                                   ""             ""
#
#                      pharm_class_moa
# 4                                 ""
# 8      BILEACID BINDING ACTIVITY MOA
# 10                                ""
# 11                                ""
# 19                                ""
# ...                              ...
# 98029                             ""
# 98041                             ""
# 98046                             ""
# 98065                             ""
# 98076                             ""
#
# [13045 rows x 11 columns]
# Index(['fda_drug_id', 'brand_name', 'generic_name', 'product_type', 'route',
#        'substance_name', 'manufacturer_name', 'pharm_class_epc',
#        'pharm_class_pe', 'pharm_class_cs', 'pharm_class_moa'],
#       dtype='object')

# %%
df.groupby('brand_name').count().sort_values('substance_name')
df_grouped = df.groupby('brand_name').agg(list)
df_grouped
#df_grouped[''] = df.groupby('brand_name')['route'].apply(list)
# Out:
#                                                   fda_drug_id  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                  [44946]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                  [28941]
# 011020 NIACINAMIDE 4  TRETINOIN 005                   [20068]
# 011021 NIACINAMIDE 4  TRETINOIN 005                   [96571]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                [82021]
# ...                                                       ...
# ZYPITAMAG                                       [2202, 23559]
# ZYPREXA                                               [75374]
# ZYTIGA                                                [38876]
# ZYVANA                                                [78025]
# ZYVOX                                   [17019, 17410, 21636]
#
#                                                                             generic_name  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025              [011010 NIACINAMIDE 4  TRETINOIN 0025]
# 011013 NIACINAMIDE 4  TRETINOIN 0025              [011013 NIACINAMIDE 4  TRETINOIN 0025]
# 011020 NIACINAMIDE 4  TRETINOIN 005                [011020 NIACINAMIDE 4  TRETINOIN 005]
# 011021 NIACINAMIDE 4  TRETINOIN 005                [011021 NIACINAMIDE 4  TRETINOIN 005]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5          [011054 NIACINAMIDE 4  SPIRONOLACTONE 5]
# ...                                                                                  ...
# ZYPITAMAG                               [PITAVASTATIN MAGNESIUM, PITAVASTATIN MAGNESIUM]
# ZYPREXA                                                                     [OLANZAPINE]
# ZYTIGA                                                             [ABIRATERONE ACETATE]
# ZYVANA                                                                          [ZYVANA]
# ZYVOX                                                  [LINEZOLID, LINEZOLID, LINEZOLID]
#
#                                                                              product_type  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                            [HUMAN PRESCRIPTION DRUG]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                            [HUMAN PRESCRIPTION DRUG]
# 011020 NIACINAMIDE 4  TRETINOIN 005                             [HUMAN PRESCRIPTION DRUG]
# 011021 NIACINAMIDE 4  TRETINOIN 005                             [HUMAN PRESCRIPTION DRUG]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                          [HUMAN PRESCRIPTION DRUG]
# ...                                                                                   ...
# ZYPITAMAG                               [HUMAN PRESCRIPTION DRUG, HUMAN PRESCRIPTION D...
# ZYPREXA                                                         [HUMAN PRESCRIPTION DRUG]
# ZYTIGA                                                          [HUMAN PRESCRIPTION DRUG]
# ZYVANA                                                          [HUMAN PRESCRIPTION DRUG]
# ZYVOX                                   [HUMAN PRESCRIPTION DRUG, HUMAN PRESCRIPTION D...
#
#                                                                    route  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                           [TOPICAL]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                           [TOPICAL]
# 011020 NIACINAMIDE 4  TRETINOIN 005                            [TOPICAL]
# 011021 NIACINAMIDE 4  TRETINOIN 005                            [TOPICAL]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                         [TOPICAL]
# ...                                                                  ...
# ZYPITAMAG                                                   [ORAL, ORAL]
# ZYPREXA                                                           [ORAL]
# ZYTIGA                                                            [ORAL]
# ZYVANA                                                            [ORAL]
# ZYVOX                                   [INTRAVENOUS, ORAL, INTRAVENOUS]
#
#                                                                            substance_name  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                              [TRETINOIN NIACINAMIDE]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                              [NIACINAMIDE TRETINOIN]
# 011020 NIACINAMIDE 4  TRETINOIN 005                               [NIACINAMIDE TRETINOIN]
# 011021 NIACINAMIDE 4  TRETINOIN 005                               [NIACINAMIDE TRETINOIN]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                       [NIACINAMIDE SPIRONOLACTONE]
# ...                                                                                   ...
# ZYPITAMAG                                                    [PITAVASTATIN, PITAVASTATIN]
# ZYPREXA                                                                      [OLANZAPINE]
# ZYTIGA                                                              [ABIRATERONE ACETATE]
# ZYVANA                                  [ASCORBIC ACID CHOLECALCIFEROL PYRIDOXINE HYDR...
# ZYVOX                                                   [LINEZOLID, LINEZOLID, LINEZOLID]
#
#                                                                         manufacturer_name  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                               [SINCERUS FLORIDA LLC]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                               [SINCERUS FLORIDA LLC]
# 011020 NIACINAMIDE 4  TRETINOIN 005                                [SINCERUS FLORIDA LLC]
# 011021 NIACINAMIDE 4  TRETINOIN 005                                [SINCERUS FLORIDA LLC]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                             [SINCERUS FLORIDA LLC]
# ...                                                                                   ...
# ZYPITAMAG                               [MEDICURE INTERNATIONAL INC, CADILA HEALTHCARE...
# ZYPREXA                                                           [ELI LILLY AND COMPANY]
# ZYTIGA                                                              [JANSSEN BIOTECH INC]
# ZYVANA                                               [STERLINGKNIGHT PHARMACEUTICALS LLC]
# ZYVOX                                   [PHARMACIA  UPJOHN COMPANY LLC, PHARMACIA  UPJ...
#
#                                                                           pharm_class_epc  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                                       [RETINOID EPC]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                                       [RETINOID EPC]
# 011020 NIACINAMIDE 4  TRETINOIN 005                                        [RETINOID EPC]
# 011021 NIACINAMIDE 4  TRETINOIN 005                                        [RETINOID EPC]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                       [ALDOSTERONE ANTAGONIST EPC]
# ...                                                                                   ...
# ZYPITAMAG                               [HMGCOA REDUCTASE INHIBITOR EPC, HMGCOA REDUCT...
# ZYPREXA                                                      [ATYPICAL ANTIPSYCHOTIC EPC]
# ZYTIGA                                                                               [""]
# ZYVANA                                                      [VITAMIN C EPC VITAMIN D EPC]
# ZYVOX                                   [OXAZOLIDINONE ANTIBACTERIAL EPC, OXAZOLIDINON...
#
#                                        pharm_class_pe  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025             [""]
# 011013 NIACINAMIDE 4  TRETINOIN 0025             [""]
# 011020 NIACINAMIDE 4  TRETINOIN 005              [""]
# 011021 NIACINAMIDE 4  TRETINOIN 005              [""]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5           [""]
# ...                                               ...
# ZYPITAMAG                                    ["", ""]
# ZYPREXA                                          [""]
# ZYTIGA                                           [""]
# ZYVANA                                           [""]
# ZYVOX                                    ["", "", ""]
#
#                                                                            pharm_class_cs  \
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                                       [RETINOIDS CS]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                                       [RETINOIDS CS]
# 011020 NIACINAMIDE 4  TRETINOIN 005                                        [RETINOIDS CS]
# 011021 NIACINAMIDE 4  TRETINOIN 005                                        [RETINOIDS CS]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                                               [""]
# ...                                                                                   ...
# ZYPITAMAG                                                                        ["", ""]
# ZYPREXA                                                                              [""]
# ZYTIGA                                                                               [""]
# ZYVANA                                                    [ASCORBIC ACID CS VITAMIN D CS]
# ZYVOX                                   [OXAZOLIDINONES CS, OXAZOLIDINONES CS, OXAZOLI...
#
#                                                                           pharm_class_moa
# brand_name
# 011010 NIACINAMIDE 4  TRETINOIN 0025                                                 [""]
# 011013 NIACINAMIDE 4  TRETINOIN 0025                                                 [""]
# 011020 NIACINAMIDE 4  TRETINOIN 005                                                  [""]
# 011021 NIACINAMIDE 4  TRETINOIN 005                                                  [""]
# 011054 NIACINAMIDE 4  SPIRONOLACTONE 5                      [ALDOSTERONE ANTAGONISTS MOA]
# ...                                                                                   ...
# ZYPITAMAG                               [HYDROXYMETHYLGLUTARYLCOA REDUCTASE INHIBITORS...
# ZYPREXA                                                                              [""]
# ZYTIGA                                                                               [""]
# ZYVANA                                                                               [""]
# ZYVOX                                                                        ["", "", ""]
#
# [4686 rows x 10 columns]

# %%
#df[df.brand_name == 'LIDOCAINE HYDROCHLORIDE']

# %%
#os.getcwd()
df_grouped.to_csv('Openfda_Drug_Deduplicated.csv')
#df_grouped
