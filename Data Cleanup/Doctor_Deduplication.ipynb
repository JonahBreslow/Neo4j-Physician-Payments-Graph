# %%
from dask import dataframe as dd

# %%
prescr = dd.read_csv('../Data/Outputs_Cleanup/Part_d/prescriber_information.csv')

# %%
phys = dd.read_csv('../Data/Outputs_Cleanup/Sunshine/physicians_info.csv')

# %%
prescr.head()
# Out:
#    Prscrbr_NPI Prscrbr_Last_Org_Name Prscrbr_First_Name Prscrbr_City  \
# 0   1003000837                  John            Richard  Santa Maria
# 1   1003001363               Stevens            Charles    El Centro
# 2   1003001645               Trivedi              Vinod   Sacramento
# 3   1003002049            Srinivasan            Lakshmi      Fremont
# 4   1003002742               Lockman              Brett       Sonora
#
#                            Prscrbr_Type
# 0                    Nurse Practitioner
# 1                       Pain Management
# 2                    Infectious Disease
# 3                         Endocrinology
# 4  Physical Medicine and Rehabilitation

# %%
phys.head()
# Out:
#    Physician_Profile_ID Physician_First_Name Physician_Middle_Name  \
# 0                485819              YAT MIN                   NaN
# 1                231734                EINAT                     R
# 2               1153066                PETER            HUNG - NGO
# 3                453780                LEILA                     M
# 4               1351245           NAGA RAMYA                   NaN
#
#   Physician_Last_Name Physician_Name_Suffix Recipient_State  \
# 0                CHEN                   NaN              FL
# 1             DUHAMEL                   NaN              CA
# 2                  VU                   NaN              CA
# 3             IRAVANI                   NaN              CA
# 4            CHOWDARY                   NaN              CA
#
#   Physician_Primary_Type                                Physician_Specialty  \
# 0         Medical Doctor  Allopathic & Osteopathic Physicians|Obstetrics...
# ...
