# %%
import json
import os
import pandas as pd
import re

# %%
files = os.listdir('../Data/openfda_json')
files = [each for each in files if each.endswith('.json')]
file_paths = ['../Data/openfda_json/' + each for each in files]
#file_paths
# Out:
# ['../Data/openfda_json/drug-label-0009-of-0010.json',
#  '../Data/openfda_json/drug-label-0008-of-0010.json',
#  '../Data/openfda_json/drug-label-0010-of-0010.json',
#  '../Data/openfda_json/drug-label-0005-of-0010.json',
#  '../Data/openfda_json/drug-label-0002-of-0010.json',
#  '../Data/openfda_json/drug-label-0003-of-0010.json',
#  '../Data/openfda_json/drug-label-0004-of-0010.json',
#  '../Data/openfda_json/drug-label-0006-of-0010.json',
#  '../Data/openfda_json/drug-label-0001-of-0010.json',
#  '../Data/openfda_json/drug-label-0007-of-0010.json']

# %%
# NOTE: This took nearly 7-9 hours to run.
my_dict = {}
df = pd.DataFrame()
for idx, file in enumerate(file_paths):
    print(f'Working on file {idx}')
    with open(file, 'r') as open_file:
        json_tmp = json.load(open_file)
    for entry in json_tmp['results']:
        df = df.append(entry['openfda'], ignore_index=True)

# %% [markdown]
# ## Save dataframe to a CSV

# %%
df.to_csv('../Data/Outputs_Cleanup/FDA/openfda.csv')

# %% [markdown]
# ## Read in dataframe and clean it up
# ## Separate step to not repeat 9 hour execution above

# %%
df = pd.read_csv('../Data/Outputs_Cleanup/FDA/openfda.csv')

# %%
df.dropna(subset=['brand_name', 'generic_name', 'manufacturer_name', 'substance_name'], inplace=True)
del df['Unnamed: 0']

# %%
columns = df.columns

# Remove []
for column in columns:
    df[column] = df[column].apply(lambda x: str(x)[1:-1] if str(x).startswith('[') else str(x))

# Remove ''
for column in columns:
    df[column] = df[column].apply(lambda x: x.replace('\'', ''))
    
df.reset_index(inplace=True)
df.rename(columns = {'index':'fda_drug_id'}, inplace=True)
df['fda_drug_id'] = 'fda'+df.fda_drug_id.astype(str)
display(df.head())
# Out:
#   fda_drug_id                brand_name  \
# 0        fda6                    Dentox
# 1       fda19       Cactus Cinis Avenae
# 2       fda22                Zinc Oxide
# 3       fda23          good sense nasal
# 4       fda33  Amantadine Hydrochloride
#
#                                         generic_name  \
# 0  BERBERIS VULGARIS, GLYCYRRHIZA GLABRA, LAPPA M...
# 1                                CACTUS CINIS AVENAE
# 2                                         ZINC OXIDE
# 3                                  OXYMETAZOLINE HCL
# 4                           AMANTADINE HYDROCHLORIDE
#
#              manufacturer_name product_ndc             product_type    route  \
# 0  BioActive Nutritional, Inc.  43857-0039           HUMAN OTC DRUG     ORAL
# 1          Uriel Pharmacy Inc.  48951-3239           HUMAN OTC DRUG     ORAL
# 2       Ultra Seal Corporation   42213-365           HUMAN OTC DRUG  TOPICAL
# 3           L. Perrigo Company   0113-0388           HUMAN OTC DRUG    NASAL
# 4          Strides Pharma Inc.   42543-493  HUMAN PRESCRIPTION DRUG     ORAL
#
#                                       substance_name  \
# 0  BERBERIS VULGARIS ROOT BARK, GLYCYRRHIZA GLABR...
# 1  MAGNESIUM PHOSPHATE, TRIBASIC, PENTAHYDRATE, S...
# 2                                         ZINC OXIDE
# 3                        OXYMETAZOLINE HYDROCHLORIDE
# 4                           AMANTADINE HYDROCHLORIDE
#
#                                  spl_id                            spl_set_id  \
# 0  e4462f59-9ba5-43a9-9b2b-3e5a807545dd  ae51c063-63b4-45cc-b8d0-e98584b65a66
# 1  b6c13079-0ed0-0d79-e053-2a95a90a8d7c  b6c13079-0ecf-0d79-e053-2a95a90a8d7c
# 2  b4c9e519-4ee3-4cba-9338-148b9cade2ac  e45ac82c-508c-4c41-ba2c-f48d36bc63fe
# 3  244eff85-348f-42a5-a26e-aaaee89bfc69  5d42adb9-3625-4072-a6b1-29a229f255c8
# 4  05b79d14-440a-4526-bccf-8bc26a2ec8a0  e4d8f36f-d668-4728-8dca-b1c22bd9aedb
#
#    ...                                                nui  \
# 0  ...  N0000185371, N0000185375, N0000175629, N000018...
# 1  ...                                                nan
# 2  ...                                                nan
# 3  ...                                                nan
# 4  ...                                                nan
#
#                                      pharm_class_epc  \
# 0  Non-Standardized Food Allergenic Extract [EPC]...
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                       pharm_class_pe  \
# 0  Increased Histamine Release [PE], Cell-mediate...
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                       pharm_class_cs  \
# 0  Allergens [CS], Dietary Proteins [CS], Plant P...
# 1                                                nan
# 2                                                nan
# 3                                                nan
# 4                                                nan
#
#                                                 unii application_number  \
# 0  1TH8Q20J0U, 2788Z9758H, 597E9BI3Z3, 11E6VI8VEG...                nan
# 1     453COF7817, 7114SV0MYK, 6OM09RPY36, OZ0E5Y15PZ                nan
# 2                                         SOI2LOH54Z            part347
# 3                                         K89MJ0S5VY            part341
# 4                                         M6Q1EO9TD0         ANDA209047
#
#      rxcui            upc original_packager_product_ndc pharm_class_moa
# 0      nan            nan                           nan             nan
# 1      nan            nan                           nan             nan
# 2   198911  0001500365569                           nan             nan
# 3  1000990            nan                           nan             nan
# 4   849389  0342543493018                           nan             nan
#
# [5 rows x 22 columns]

# %%
def remove_punc(string):
    '''
    takes in a string and removed all punctuation.
    '''
    return re.sub(r'[^\w\s]','',string)

def preProcess(df):
    '''
    takes a dataframe, applies the remove_punc function
    and then upper cases all text columns
    '''
    df = df.applymap(lambda s:remove_punc(s).upper() if isinstance(s, str) else s)
    return df

# %%
df['manufacturer_name_normalized'] = preProcess(df[['manufacturer_name']])
manu = df[['manufacturer_name_normalized']].copy().drop_duplicates()
manu.reset_index(inplace=True)
manu.columns = ['fda_manuf_id', 'manufacturer_name_normalized']
manu['fda_manuf_id'] = manu['fda_manuf_id'].apply(lambda x: 'fda' + str(x))
df = df.merge(manu, how='left', on='manufacturer_name_normalized')
df
#df['fda_manuf_id'] = 'fda' + str(df['manufacturer_name_normalized'].apply(hash))
#df['fda_manuf_id'].unique()
#df_manuf.head()
#df_manuf.csv('../Data/Outputs_Cleanup/FDA/')
# Out:
#       fda_drug_id                                         brand_name  \
# 0            fda6                                             Dentox
# 1           fda19                                Cactus Cinis Avenae
# 2           fda22                                         Zinc Oxide
# 3           fda23                                   good sense nasal
# 4           fda33                           Amantadine Hydrochloride
# ...           ...                                                ...
# 98090   fda193147                       Jack Nicklaus hand sanitizer
# 98091   fda193148  Rexall Medicated WipesHemorrhoidal wipe Hemorr...
# 98092   fda193149                          Minocycline Hydrochloride
# 98093   fda193150                                 HAND SANITIZER SET
# 98094   fda193151              Essentials by Catalina Hand Sanitizer
#
#                                             generic_name  \
# 0      BERBERIS VULGARIS, GLYCYRRHIZA GLABRA, LAPPA M...
# 1                                    CACTUS CINIS AVENAE
# 2                                             ZINC OXIDE
# 3                                      OXYMETAZOLINE HCL
# 4                               AMANTADINE HYDROCHLORIDE
# ...                                                  ...
# 98090                                            ALCOHOL
# 98091                                        WITCH HAZEL
# 98092                          MINOCYCLINE HYDROCHLORIDE
# 98093                                            ALCOHOL
# 98094                                            ALCOHOL
#
#                  manufacturer_name product_ndc             product_type  \
# 0      BioActive Nutritional, Inc.  43857-0039           HUMAN OTC DRUG
# 1              Uriel Pharmacy Inc.  48951-3239           HUMAN OTC DRUG
# 2           Ultra Seal Corporation   42213-365           HUMAN OTC DRUG
# 3               L. Perrigo Company   0113-0388           HUMAN OTC DRUG
# 4              Strides Pharma Inc.   42543-493  HUMAN PRESCRIPTION DRUG
# ...                            ...         ...                      ...
# 98090    Shalom International Corp   73025-063           HUMAN OTC DRUG
# 98091              Dolgencorp, LLC   55910-105           HUMAN OTC DRUG
# 98092  PD-Rx Pharmaceuticals, Inc.   55289-201  HUMAN PRESCRIPTION DRUG
# 98093  Double Body Biotech Limited   74657-004           HUMAN OTC DRUG
# 98094         Maki Creations, Inc.   76902-026           HUMAN OTC DRUG
#
#          route                                     substance_name  \
# 0         ORAL  BERBERIS VULGARIS ROOT BARK, GLYCYRRHIZA GLABR...
# 1         ORAL  MAGNESIUM PHOSPHATE, TRIBASIC, PENTAHYDRATE, S...
# 2      TOPICAL                                         ZINC OXIDE
# 3        NASAL                        OXYMETAZOLINE HYDROCHLORIDE
# 4         ORAL                           AMANTADINE HYDROCHLORIDE
# ...        ...                                                ...
# 98090  TOPICAL                                            ALCOHOL
# 98091  TOPICAL                                        WITCH HAZEL
# 98092     ORAL                          MINOCYCLINE HYDROCHLORIDE
# 98093  TOPICAL                                            ALCOHOL
# 98094  TOPICAL                                            ALCOHOL
#
#                                      spl_id  \
# 0      e4462f59-9ba5-43a9-9b2b-3e5a807545dd
# 1      b6c13079-0ed0-0d79-e053-2a95a90a8d7c
# 2      b4c9e519-4ee3-4cba-9338-148b9cade2ac
# 3      244eff85-348f-42a5-a26e-aaaee89bfc69
# 4      05b79d14-440a-4526-bccf-8bc26a2ec8a0
# ...                                     ...
# 98090  aa194dfd-a8f9-a746-e053-2a95a90a5311
# 98091  a8fdf1fc-0184-7a76-e053-2995a90a6ba6
# 98092  a8ad7f35-806d-5e7f-e053-2995a90a73c7
# 98093  ac086e51-eeaa-4aa5-e053-2a95a90a1154
# 98094  a5f30eba-4aa4-5c51-e053-2a95a90ab28c
#
#                                  spl_set_id  ...  \
# 0      ae51c063-63b4-45cc-b8d0-e98584b65a66  ...
# 1      b6c13079-0ecf-0d79-e053-2a95a90a8d7c  ...
# 2      e45ac82c-508c-4c41-ba2c-f48d36bc63fe  ...
# 3      5d42adb9-3625-4072-a6b1-29a229f255c8  ...
# 4      e4d8f36f-d668-4728-8dca-b1c22bd9aedb  ...
# ...                                     ...  ...
# 98090  0ed5e5da-888f-4f4d-b990-828a3e64236a  ...
# 98091  2055289d-962e-46a9-b371-b5bb93dd46b4  ...
# 98092  87a137c6-dd53-44d3-ab49-ef78ebed35c8  ...
# 98093  a9d4d100-44e1-dd96-e053-2995a90a0a5e  ...
# 98094  a5f30eba-4aa3-5c51-e053-2a95a90ab28c  ...
#
#                                           pharm_class_pe  \
# 0      Increased Histamine Release [PE], Cell-mediate...
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 98090                                                nan
# 98091                                                nan
# 98092                                                nan
# 98093                                                nan
# 98094                                                nan
#
#                                           pharm_class_cs  \
# 0      Allergens [CS], Dietary Proteins [CS], Plant P...
# 1                                                    nan
# 2                                                    nan
# 3                                                    nan
# 4                                                    nan
# ...                                                  ...
# 98090                                                nan
# 98091                                                nan
# 98092                                                nan
# 98093                                                nan
# 98094                                                nan
#
#                                                     unii application_number  \
# 0      1TH8Q20J0U, 2788Z9758H, 597E9BI3Z3, 11E6VI8VEG...                nan
# 1         453COF7817, 7114SV0MYK, 6OM09RPY36, OZ0E5Y15PZ                nan
# 2                                             SOI2LOH54Z            part347
# 3                                             K89MJ0S5VY            part341
# 4                                             M6Q1EO9TD0         ANDA209047
# ...                                                  ...                ...
# 98090                                         3K9958V90M           part333E
# 98091                                         101I4J0U34            part346
# 98092                                         0020414E5U         ANDA063065
# 98093                                         3K9958V90M           part333A
# 98094                                         3K9958V90M           part333A
#
#          rxcui                                                upc  \
# 0          nan                                                nan
# 1          nan                                                nan
# 2       198911                                      0001500365569
# 3      1000990                                                nan
# 4       849389                                      0342543493018
# ...        ...                                                ...
# 98090   581660                                      0020748266889
# 98091   844379                                      0074887624802
# 98092   197984                                                nan
# 98093  1305100                                                nan
# 98094      nan  0766897077470, 0766897077425, 0766897077524, 0...
#
#       original_packager_product_ndc pharm_class_moa  \
# 0                               nan             nan
# 1                               nan             nan
# 2                               nan             nan
# 3                               nan             nan
# 4                               nan             nan
# ...                             ...             ...
# 98090                           nan             nan
# 98091                           nan             nan
# 98092                     0591-5695             nan
# 98093                           nan             nan
# 98094                           nan             nan
#
#       manufacturer_name_normalized fda_manuf_id
# 0        BIOACTIVE NUTRITIONAL INC         fda0
# 1               URIEL PHARMACY INC         fda1
# 2           ULTRA SEAL CORPORATION         fda2
# 3                L PERRIGO COMPANY         fda3
# 4               STRIDES PHARMA INC         fda4
# ...                            ...          ...
# 98090    SHALOM INTERNATIONAL CORP       fda665
# 98091               DOLGENCORP LLC       fda655
# 98092     PDRX PHARMACEUTICALS INC         fda6
# 98093  DOUBLE BODY BIOTECH LIMITED      fda3613
# 98094           MAKI CREATIONS INC     fda82653
#
# [98095 rows x 24 columns]

# %%
df.to_csv('../Data/Outputs_Cleanup/FDA/openfda_processed.csv')
