# %%
import json
import os
import pandas as pd

# %%
# NOTE: This took nearly 7-9 hours to run.
my_dict = {}
df = pd.DataFrame()
for idx, file in enumerate(file_paths):
    print(f'Working on file {idx}')
    with open(file, 'r') as open_file:
        json_tmp = json.load(open_file)
    for entry in json_tmp['results']:
        df = df.append(entry['openfda'], ignore_index=True)
# Out:
# Working on file 0
# Working on file 1
# Working on file 2
# Working on file 3
# Working on file 4
# Working on file 5
# Working on file 6
# Working on file 7
# Working on file 8
# Working on file 9

# %% [markdown]
# ## Save dataframe to a CSV

# %%
df.to_csv('openfda.csv')

# %% [markdown]
# ## Read in dataframe and clean it up
# ## Separate step to not repeat 9 hour execution above

# %%
df = pd.read_csv('openfda.csv')

# %%
df.dropna(subset=['brand_name', 'generic_name', 'manufacturer_name', 'substance_name'], inplace=True)
del df['Unnamed: 0']

# %%
columns = df.columns

# Remove []
for column in columns:
    df[column] = df[column].apply(lambda x: str(x)[1:-1] if str(x).startswith('[') else str(x))

# Remove ''
for column in columns:
    df[column] = df[column].apply(lambda x: x.replace('\'', ''))
    
display(df.head())

df.to_csv('openfda_processed.csv')
# Out:
#                   brand_name  \
# 6                     Dentox
# 19       Cactus Cinis Avenae
# 22                Zinc Oxide
# 23          good sense nasal
# 33  Amantadine Hydrochloride
#
#                                          generic_name  \
# 6   BERBERIS VULGARIS, GLYCYRRHIZA GLABRA, LAPPA M...
# 19                                CACTUS CINIS AVENAE
# 22                                         ZINC OXIDE
# 23                                  OXYMETAZOLINE HCL
# 33                           AMANTADINE HYDROCHLORIDE
#
#               manufacturer_name product_ndc             product_type    route  \
# 6   BioActive Nutritional, Inc.  43857-0039           HUMAN OTC DRUG     ORAL
# 19          Uriel Pharmacy Inc.  48951-3239           HUMAN OTC DRUG     ORAL
# 22       Ultra Seal Corporation   42213-365           HUMAN OTC DRUG  TOPICAL
# 23           L. Perrigo Company   0113-0388           HUMAN OTC DRUG    NASAL
# 33          Strides Pharma Inc.   42543-493  HUMAN PRESCRIPTION DRUG     ORAL
#
#                                        substance_name  \
# 6   BERBERIS VULGARIS ROOT BARK, GLYCYRRHIZA GLABR...
# 19  MAGNESIUM PHOSPHATE, TRIBASIC, PENTAHYDRATE, S...
# 22                                         ZINC OXIDE
# 23                        OXYMETAZOLINE HYDROCHLORIDE
# 33                           AMANTADINE HYDROCHLORIDE
#
#                                   spl_id  \
# 6   e4462f59-9ba5-43a9-9b2b-3e5a807545dd
# 19  b6c13079-0ed0-0d79-e053-2a95a90a8d7c
# 22  b4c9e519-4ee3-4cba-9338-148b9cade2ac
# 23  244eff85-348f-42a5-a26e-aaaee89bfc69
# 33  05b79d14-440a-4526-bccf-8bc26a2ec8a0
#
#                               spl_set_id                 package_ndc  ...  \
# 6   ae51c063-63b4-45cc-b8d0-e98584b65a66                43857-0039-1  ...
# 19  b6c13079-0ecf-0d79-e053-2a95a90a8d7c                48951-3239-1  ...
# 22  e45ac82c-508c-4c41-ba2c-f48d36bc63fe  42213-365-56, 42213-365-48  ...
# 23  5d42adb9-3625-4072-a6b1-29a229f255c8                0113-0388-10  ...
# 33  e4d8f36f-d668-4728-8dca-b1c22bd9aedb  42543-493-01, 42543-493-05  ...
#
#                                                   nui  \
# 6   N0000185371, N0000185375, N0000175629, N000018...
# 19                                                nan
# 22                                                nan
# 23                                                nan
# 33                                                nan
#
#                                       pharm_class_epc  \
# 6   Non-Standardized Food Allergenic Extract [EPC]...
# 19                                                nan
# 22                                                nan
# 23                                                nan
# 33                                                nan
#
#                                        pharm_class_pe  \
# 6   Increased Histamine Release [PE], Cell-mediate...
# 19                                                nan
# 22                                                nan
# 23                                                nan
# 33                                                nan
#
#                                        pharm_class_cs  \
# 6   Allergens [CS], Dietary Proteins [CS], Plant P...
# 19                                                nan
# 22                                                nan
# 23                                                nan
# 33                                                nan
#
#                                                  unii application_number  \
# 6   1TH8Q20J0U, 2788Z9758H, 597E9BI3Z3, 11E6VI8VEG...                nan
# 19     453COF7817, 7114SV0MYK, 6OM09RPY36, OZ0E5Y15PZ                nan
# 22                                         SOI2LOH54Z            part347
# 23                                         K89MJ0S5VY            part341
# 33                                         M6Q1EO9TD0         ANDA209047
#
#       rxcui            upc original_packager_product_ndc pharm_class_moa
# 6       nan            nan                           nan             nan
# 19      nan            nan                           nan             nan
# 22   198911  0001500365569                           nan             nan
# 23  1000990            nan                           nan             nan
# 33   849389  0342543493018                           nan             nan
#
# [5 rows x 21 columns]
